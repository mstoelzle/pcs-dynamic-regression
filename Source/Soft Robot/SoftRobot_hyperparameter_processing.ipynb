# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results/20230809_155657_ns-1_dof-1.csv')

# %%
df
# Out:
#       batch_size  learning_rate  lambda  lr_increment  lambda_increment  seed  \
# 0           1000   1.000000e-12     0.1             1               1.0     0
# 1           1000   1.000000e-12     0.1             1               1.0     1
# 2           1000   1.000000e-12     0.1             1               0.5     0
# 3           1000   1.000000e-12     0.1             1               0.5     1
# 4           1000   1.000000e-12     0.1             1               0.1     0
# ...          ...            ...     ...           ...               ...   ...
# 3163         100   1.000000e-06     5.0            10               1.0     1
# 3164         100   1.000000e-06     5.0            10               0.5     0
# 3165         100   1.000000e-06     5.0            10               0.5     1
# 3166         100   1.000000e-06     5.0            10               0.1     0
# 3167         100   1.000000e-06     5.0            10               0.1     1
#
# ...

# %%
df['loss_stage_3'].idxmin()
# Out:
# 148

# %%
df.sort_values(by=['loss_stage_3']).head(15)
# Out:
#       batch_size  learning_rate  lambda  lr_increment  lambda_increment  seed  \
# 148         1000   1.000000e-10     0.1             1               0.1     0
# 154         1000   1.000000e-10     0.1             2               0.1     0
# 220         1000   5.000000e-10     0.1             1               0.1     0
# 940          500   1.000000e-10     0.1             1               0.1     0
# 292         1000   1.000000e-09     0.1             1               0.1     0
# 88          1000   1.000000e-11     0.1            10               0.1     0
# 1666         200   1.000000e-11     0.1             2               0.1     0
# 226         1000   5.000000e-10     0.1             2               0.1     0
# 2452         100   1.000000e-11     0.1             1               0.1     0
# 808          500   1.000000e-12     0.1            10               0.1     0
# 946          500   1.000000e-10     0.1             2               0.1     0
# ...
